# %%
import cv2
import numpy as np
from keras.models import load_model

# Load your trained Food101 model
model = load_model('./classification.h5')

# List of labels from Food101 (adjust if necessary)
labels = [
    "Apple pie", "Baby back ribs", "Baklava", "Beef carpaccio", "Beef tartare", "Beet salad", "Beignets", "Bibimbap",
    "Bread pudding", "Breakfast burrito", "Bruschetta", "Caesar salad", "Cannoli", "Caprese salad", "Carrot cake",
    "Ceviche", "Cheesecake", "Cheese plate", "Chicken curry", "Chicken quesadilla", "Chicken wings", "Chocolate cake",
    "Chocolate mousse", "Churros", "Clam chowder", "Club sandwich", "Crab cakes", "Creme brulee", "Croque madame",
    "Cup cakes", "Deviled eggs", "Donuts", "Dumplings", "Edamame", "Eggs benedict", "Escargots", "Falafel",
    "Filet mignon", "Fish and chips", "Foie gras", "French fries", "French onion soup", "French toast", "Fried calamari",
    "Fried rice", "Frozen yogurt", "Garlic bread", "Gnocchi", "Greek salad", "Grilled cheese sandwich", "Grilled salmon",
    "Guacamole", "Gyoza", "Hamburger", "Hot and sour soup", "Hot dog", "Huevos rancheros", "Hummus", "Ice cream",
    "Lasagna", "Lobster bisque", "Lobster roll sandwich", "Macaroni and cheese", "Macarons", "Miso soup", "Mussels",
    "Nachos", "Omelette", "Onion rings", "Oysters", "Pad thai", "Paella", "Pancakes", "Panna cotta", "Peking duck",
    "Pho", "Pizza", "Pork chop", "Poutine", "Prime rib", "Pulled pork sandwich", "Ramen", "Ravioli", "Red velvet cake",
    "Risotto", "Samosa", "Sashimi", "Scallops", "Seaweed salad", "Shrimp and grits", "Spaghetti bolognese",
    "Spaghetti carbonara", "Spring rolls", "Steak", "Strawberry shortcake", "Sushi", "Tacos", "Takoyaki", "Tiramisu",
    "Tuna tartare", "Waffles"
]

def recognize_food(image_path):
    # Load and preprocess the image
    img = cv2.imread(image_path)
    img_resized = cv2.resize(img, (640, 640))  # Resize to model input size (e.g., InceptionV3 size)
    img_normalized = img_resized / 255.0  # Normalize the image
    img_expanded = np.expand_dims(img_normalized, axis=0)  # Add batch dimension

    # Make a prediction
    predictions = model.predict(img_expanded)
    predicted_class = np.argmax(predictions[0])
    confidence = predictions[0][predicted_class]

    # Display the result
    label_text = f"{labels[predicted_class]}: {confidence:.2f}"
    print(label_text)

    # Draw the label on the image and display it
    cv2.putText(img, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow("Food Recognition", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage
image_path = "C:/Users/33237/Desktop/2.png"
recognize_food(image_path)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a75cb2283c96> in <module>
#       4
#       5 # Load your trained Food101 model
# ----> 6 model = load_model('./classification.h5')
#       7
#       8 # List of labels from Food101 (adjust if necessary)
#
# D:\conda\envs\volume\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     417     f = h5dict(filepath, 'r')
#     418     try:
# --> 419         model = _deserialize_model(f, custom_objects, compile)
#     420     finally:
#     421         if opened_new_file:
#
# D:\conda\envs\volume\lib\site-packages\keras\engine\saving.py in _deserialize_model(f, custom_objects, compile)
#     223         raise ValueError('No model found in config.')
#     224     model_config = json.loads(model_config.decode('utf-8'))
# --> 225     model = model_from_config(model_config, custom_objects=custom_objects)
#     226     model_weights_group = f['model_weights']
#     227
#
# D:\conda\envs\volume\lib\site-packages\keras\engine\saving.py in model_from_config(config, custom_objects)
#     456                         '`Sequential.from_config(config)`?')
#     457     from ..layers import deserialize
# --> 458     return deserialize(config, custom_objects=custom_objects)
#     459
#     460
#
# D:\conda\envs\volume\lib\site-packages\keras\layers\__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# D:\conda\envs\volume\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     136             if cls is None:
#     137                 raise ValueError('Unknown ' + printable_module_name +
# --> 138                                  ': ' + class_name)
#     139         if hasattr(cls, 'from_config'):
#     140             custom_objects = custom_objects or {}
#
# ValueError: Unknown layer: Functional

# %%
import cv2
import numpy as np
from keras.models import load_model

print("11111")

# Load your trained Food101 model
model = load_model('./classification.keras')
model.save('./classification.h5')

print("11111")

# List of labels from Food101 (adjust if necessary)
labels = [
    "Apple pie", "Baby back ribs", "Baklava", "Beef carpaccio", "Beef tartare", "Beet salad", "Beignets", "Bibimbap",
    "Bread pudding", "Breakfast burrito", "Bruschetta", "Caesar salad", "Cannoli", "Caprese salad", "Carrot cake",
    "Ceviche", "Cheesecake", "Cheese plate", "Chicken curry", "Chicken quesadilla", "Chicken wings", "Chocolate cake",
    "Chocolate mousse", "Churros", "Clam chowder", "Club sandwich", "Crab cakes", "Creme brulee", "Croque madame",
    "Cup cakes", "Deviled eggs", "Donuts", "Dumplings", "Edamame", "Eggs benedict", "Escargots", "Falafel",
    "Filet mignon", "Fish and chips", "Foie gras", "French fries", "French onion soup", "French toast", "Fried calamari",
    "Fried rice", "Frozen yogurt", "Garlic bread", "Gnocchi", "Greek salad", "Grilled cheese sandwich", "Grilled salmon",
    "Guacamole", "Gyoza", "Hamburger", "Hot and sour soup", "Hot dog", "Huevos rancheros", "Hummus", "Ice cream",
    "Lasagna", "Lobster bisque", "Lobster roll sandwich", "Macaroni and cheese", "Macarons", "Miso soup", "Mussels",
    "Nachos", "Omelette", "Onion rings", "Oysters", "Pad thai", "Paella", "Pancakes", "Panna cotta", "Peking duck",
    "Pho", "Pizza", "Pork chop", "Poutine", "Prime rib", "Pulled pork sandwich", "Ramen", "Ravioli", "Red velvet cake",
    "Risotto", "Samosa", "Sashimi", "Scallops", "Seaweed salad", "Shrimp and grits", "Spaghetti bolognese",
    "Spaghetti carbonara", "Spring rolls", "Steak", "Strawberry shortcake", "Sushi", "Tacos", "Takoyaki", "Tiramisu",
    "Tuna tartare", "Waffles"
]

def pad_to_square(image):
    """
    Pads the input image to make it square.
    """
    height, width, _ = image.shape
    size = max(height, width)
    top = (size - height) // 2
    bottom = size - height - top
    left = (size - width) // 2
    right = size - width - left
    padded_image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=(0, 0, 0))
    return padded_image

def recognize_food(image_path):
    # Load and preprocess the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to read image from {image_path}")
        return

    img_padded = pad_to_square(img)  # Pad the image to make it square
    img_resized = cv2.resize(img_padded, (640, 640))  # Resize to model input size
    img_normalized = img_resized / 255.0  # Normalize the image
    img_expanded = np.expand_dims(img_normalized, axis=0)  # Add batch dimension

    # Save the resized image for visualization
    padded_image_path = "padded_image.jpg"
    cv2.imwrite(padded_image_path, img_resized * 255)  # Save with pixel values restored
    print(f"Padded image saved to {padded_image_path}")

    # Make a prediction
    predictions = model.predict(img_expanded)
    predicted_class = np.argmax(predictions[0])
    confidence = predictions[0][predicted_class]

    # Display the result
    label_text = f"{labels[predicted_class]}: {confidence:.2f}"
    print(label_text)

    # Draw the label on the original image and display it
    cv2.putText(img, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    cv2.imshow("Food Recognition", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage
image_path = "C:/Users/33237/Desktop/ps.jpg"
recognize_food(image_path)
# Out:
# 11111
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-99425f048d60> in <module>
#       6
#       7 # Load your trained Food101 model
# ----> 8 model = load_model('./classification.keras')
#       9 model.save('./classification.h5')
#      10
#
# D:\conda\envs\volume\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     415     model = None
#     416     opened_new_file = not isinstance(filepath, h5py.Group)
# --> 417     f = h5dict(filepath, 'r')
#     418     try:
#     419         model = _deserialize_model(f, custom_objects, compile)
#
# D:\conda\envs\volume\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     184             self._is_file = False
#     185         elif isinstance(path, str):
# --> 186             self.data = h5py.File(path, mode=mode)
#     187             self._is_file = True
#     188         elif isinstance(path, dict):
#
# D:\conda\envs\volume\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# D:\conda\envs\volume\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)
