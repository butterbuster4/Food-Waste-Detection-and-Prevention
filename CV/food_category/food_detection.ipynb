# %%
from ultralytics import YOLO
import cv2  
import matplotlib.pyplot as plt

# %%
image_path = "C:/Users/33237/Desktop/rg.jpg"

# %%
model = YOLO("./best.pt")

print("model loaded successfully!")
# Out:
# model loaded successfully!

# %%
results = model(image_path)

print("result generated successfully!")
# Out:
# image 1/1 C:\Users\33237\Desktop\rg.jpg: 448x640 2 foods, 362.3ms
# Speed: 26.0ms preprocess, 362.3ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# result generated successfully!

# %%
image = cv2.imread(image_path)

print("Image read successfully!")
# Out:
# Image read successfully!

# %%
for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0]) 
        class_id = int(box.cls) 
        confidence = box.conf.item()

        class_name = model.names[class_id]

        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2) 

        label = f"{class_name} ({confidence:.2f})"
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.axis("off")  
plt.show()
